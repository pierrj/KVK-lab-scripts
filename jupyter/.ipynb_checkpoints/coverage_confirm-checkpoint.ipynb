# %%
import csv
from itertools import groupby
import statistics
import timeit
import sys

# %%
with open('/global/home/users/pierrj/testfiles/500.confirmed', newline = '') as confirmed:
    confirmed_reader = csv.reader(confirmed, delimiter = '\t')
    confirmed_list = [[int(row[0]), int(row[1]), int(row[2])] for row in confirmed_reader]

# %%
with open('/global/scratch/users/pierrj/eccDNA/magnaporthe_pureculture/rawdata/illumina/G3_1A_tests/parallel.confirmed') as confirmedall:
    confirmedall_reader = csv.reader(confirmedall, delimiter = '\t')
    confirmedall_list = [[int(row[0]), int(row[1]), int(row[2])] for row in confirmedall_reader]

# %%
with open('/global/scratch/users/pierrj/eccDNA/magnaporthe_pureculture/rawdata/illumina/G3_1A_tests/genomecoverage.mergedandpe.G3_1A_bwamem.bed') as coverage:
    coverage_reader = csv.reader(coverage, delimiter = '\t')
    coverage_indexed = [[] for i in range(56)]
    for row in coverage_reader:
        coverage_indexed[(int(row[0][10:12])-1)].append([int(row[1]) -1, int(row[2])])

# %%
def get_size(obj, seen=None):

    """Recursively finds size of objects"""

    size = sys.getsizeof(obj)

    if seen is None:

        seen = set()

    obj_id = id(obj)

    if obj_id in seen:

        return 0

    # Important mark as seen *before* entering recursion to gracefully handle

    # self-referential objects

    seen.add(obj_id)

    if isinstance(obj, dict):

        size += sum([get_size(v, seen) for v in obj.values()])

        size += sum([get_size(k, seen) for k in obj.keys()])

    elif hasattr(obj, '__dict__'):

        size += get_size(obj.__dict__, seen)

    elif hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):

        size += sum([get_size(i, seen) for i in obj])

    return size

# %%
print(get_size(coverage_indexed))
# Out:
# 5071263964

# %%
def checkcoverage(ecc):
    region_len = ecc[2] - ecc[1]
    region = coverage_indexed[ecc[0]][ecc[1]:(ecc[2]+1)]
    region_cov = [region[i][1] for i in range(len(region))]
    beforestart = ecc[1] - 1 - region_len
    if beforestart <= 0:
        return 'region too close to start'
    afterstart = ecc[2] + 1
    if afterstart + region_len > coverage_indexed[ecc[0]][-1][0]:
        return 'region too close to end'
    region_before = coverage_indexed[ecc[0]][beforestart:beforestart + 1 + region_len]
    region_before_cov = [region_before[i][1] for i in range(len(region_before))]
    region_after = coverage_indexed[ecc[0]][afterstart:afterstart + 1 + region_len]
    region_after_cov = [region_after[i][1] for i in range(len(region_after))]
    mean_region = statistics.mean(region_cov)
    mean_before = statistics.mean(region_before_cov)
    mean_after = statistics.mean(region_after_cov)
    if mean_region >= (2*mean_before) and mean_region >= (2*mean_after):
        return 'true'
    else:
        return 'coverage too low'

# %%
for i in range(len(confirmed_list)):
    ecc = confirmed_list[i]
    region_len = ecc[2] - ecc[1]
    region = coverage_indexed[ecc[0]][ecc[1]:(ecc[2]+1)]
    region_cov = [region[i][1] for i in range(len(region))]
    beforestart = ecc[1] - 1 - region_len
    if beforestart <= 0:
        ecc.append('lconf')
        ecc.append('too close to start')
        print(ecc)
        continue
    afterstart = ecc[2] + 1
    if afterstart + region_len > coverage_indexed[ecc[0]][-1][0]:
        ecc.append('lconf')
        ecc.append('too close to end')
        print(ecc)
        continue
    region_before = coverage_indexed[ecc[0]][beforestart:beforestart + 1 + region_len]
    region_before_cov = [region_before[i][1] for i in range(len(region_before))]
    region_after = coverage_indexed[ecc[0]][afterstart:afterstart + 1 + region_len]
    region_after_cov = [region_after[i][1] for i in range(len(region_after))]
    mean_region = statistics.mean(region_cov)
    mean_before = statistics.mean(region_before_cov)
    mean_after = statistics.mean(region_after_cov)
    if mean_region >= (2*mean_before) and mean_region >= (2*mean_after):
        ecc.append('hconf')
        ecc.append('none')
    else:
        ecc.append('lconf')
        ecc.append('coverage too low')
    print(ecc)
# Out:
# [14, 70735, 71303, 'hconf', 'none']
# [14, 349128, 349764, 'hconf', 'none']
# [2, 1674894, 1680235, 'lconf', 'coverage too low']
# [12, 355104, 356042, 'lconf', 'coverage too low']
# [2, 626071, 627316, 'hconf', 'none']
# [21, 209465, 209961, 'lconf', 'coverage too low']
# [4, 2696604, 2699034, 'lconf', 'coverage too low']
# [14, 132347, 132906, 'lconf', 'coverage too low']
# [9, 932917, 935653, 'lconf', 'coverage too low']
# [5, 1887602, 1889159, 'hconf', 'none']
# [8, 166497, 166880, 'hconf', 'none']
# [4, 3034338, 3034647, 'lconf', 'coverage too low']
# [1, 4945547, 4946469, 'lconf', 'coverage too low']
# [2, 573874, 575341, 'lconf', 'coverage too low']
# [11, 748313, 748925, 'lconf', 'coverage too low']
# [2, 3611761, 3616320, 'hconf', 'none']
# [7, 1295634, 1297723, 'lconf', 'coverage too low']
# [2, 3923725, 3924836, 'lconf', 'coverage too low']
# [4, 1884379, 1885179, 'lconf', 'coverage too low']
# [3, 1200621, 1200838, 'hconf', 'none']
# [8, 1087179, 1087434, 'hconf', 'none']
# [3, 3985805, 3986558, 'hconf', 'none']
# [12, 284307, 284726, 'lconf', 'coverage too low']
# [1, 2723079, 2723598, 'lconf', 'coverage too low']
# [4, 514531, 514923, 'lconf', 'coverage too low']
# [5, 1798055, 1799288, 'hconf', 'none']
# [0, 2572624, 2601296, 'lconf', 'coverage too low']
# [5, 1639975, 1640643, 'hconf', 'none']
# [2, 42591, 969033, 'lconf', 'too close to start']
# [2, 969033, 974891, 'hconf', 'none']
# [6, 301843, 302179, 'lconf', 'coverage too low']
# [1, 3651347, 3651857, 'lconf', 'coverage too low']
# [1, 2975018, 2975126, 'hconf', 'none']
# [0, 2766710, 2767281, 'lconf', 'coverage too low']
# [1, 4781704, 4783066, 'lconf', 'coverage too low']
# [4, 903719, 904716, 'hconf', 'none']
# [3, 2745821, 2747117, 'lconf', 'coverage too low']
# [3, 1922629, 1923069, 'lconf', 'coverage too low']
# [1, 3122436, 3122929, 'lconf', 'coverage too low']
# [18, 16213, 17324, 'lconf', 'coverage too low']
# [2, 2233907, 2234838, 'hconf', 'none']
# [0, 1856983, 1857333, 'hconf', 'none']
# [13, 629643, 630109, 'lconf', 'coverage too low']
# [4, 2329237, 2331733, 'lconf', 'coverage too low']
# [6, 1706117, 1706658, 'lconf', 'coverage too low']
# [0, 14440, 14942, 'lconf', 'coverage too low']
# [2, 1470754, 1471298, 'hconf', 'none']
# [1, 2714934, 2715312, 'lconf', 'coverage too low']
# [5, 1519529, 1519809, 'hconf', 'none']
# [0, 1677271, 1677565, 'hconf', 'none']
# [0, 1804500, 1805152, 'lconf', 'coverage too low']
# [5, 1920942, 1925468, 'lconf', 'coverage too low']
# [0, 1677271, 1677564, 'hconf', 'none']
# [5, 1791093, 1793324, 'lconf', 'coverage too low']
# [7, 2242641, 2242923, 'lconf', 'coverage too low']
# [0, 1340091, 1340368, 'hconf', 'none']
# [2, 730829, 732219, 'lconf', 'coverage too low']
# [1, 2097523, 2097808, 'lconf', 'coverage too low']
# [7, 1846788, 1847725, 'lconf', 'coverage too low']
# [7, 1085359, 1087331, 'lconf', 'coverage too low']
# [2, 452875, 453108, 'hconf', 'none']
# [1, 4415899, 4416370, 'lconf', 'coverage too low']
# [3, 3936947, 3939630, 'lconf', 'coverage too low']
# [6, 2061409, 2061895, 'lconf', 'coverage too low']
# [2, 231470, 232258, 'lconf', 'coverage too low']
# [5, 2078134, 2078497, 'lconf', 'coverage too low']
# [35, 4, 403, 'lconf', 'too close to start']
# [2, 710837, 711176, 'lconf', 'coverage too low']
# [6, 2189778, 2191652, 'lconf', 'coverage too low']
# [16, 82152, 82653, 'hconf', 'none']
# [0, 178951, 179519, 'hconf', 'none']
# [25, 6233, 6490, 'lconf', 'coverage too low']
# [9, 498138, 499265, 'hconf', 'none']
# [2, 1289410, 1289880, 'lconf', 'coverage too low']
# [2, 4174892, 4177022, 'lconf', 'coverage too low']
# [11, 21162, 913303, 'lconf', 'too close to start']
# [2, 1902558, 1906340, 'lconf', 'coverage too low']
# [2, 4526105, 4527865, 'hconf', 'none']
# [16, 330727, 331446, 'lconf', 'coverage too low']
# [6, 49164, 52890, 'lconf', 'coverage too low']
# [45, 5836, 6417, 'hconf', 'none']
# [3, 15123, 15608, 'hconf', 'none']
# [5, 1328682, 1332038, 'lconf', 'coverage too low']
# [2, 1149023, 1149276, 'lconf', 'coverage too low']
# [0, 3976642, 3978994, 'lconf', 'coverage too low']
# [1, 2311215, 2313319, 'hconf', 'none']
# [1, 2311211, 2313319, 'hconf', 'none']
# [9, 498138, 499273, 'hconf', 'none']
# [4, 894270, 894661, 'lconf', 'coverage too low']
# [3, 2730443, 2733401, 'lconf', 'coverage too low']
# [2, 95124, 96173, 'lconf', 'coverage too low']
# [4, 47461, 51154, 'lconf', 'coverage too low']
# [1, 1210323, 1213191, 'lconf', 'coverage too low']
# [1, 3530958, 3532187, 'lconf', 'coverage too low']
# [2, 2237941, 2241094, 'lconf', 'coverage too low']
# [10, 615371, 617634, 'hconf', 'none']
# [4, 2146296, 2149569, 'lconf', 'coverage too low']
# [0, 4176626, 4180066, 'lconf', 'coverage too low']
# [8, 483871, 484206, 'hconf', 'none']
# [0, 4613259, 4614194, 'lconf', 'coverage too low']
# [1, 2694761, 2695284, 'hconf', 'none']
# [1, 594231, 594624, 'lconf', 'coverage too low']
# [1, 2668065, 2670921, 'hconf', 'none']
# [3, 2646479, 2647141, 'lconf', 'coverage too low']
# [22, 67333, 69038, 'hconf', 'none']
# [1, 711367, 712351, 'lconf', 'coverage too low']
# [12, 177402, 178990, 'lconf', 'coverage too low']
# [46, 2271, 2821, 'hconf', 'none']
# [4, 1000210, 1001565, 'lconf', 'coverage too low']
# [18, 77480, 77977, 'hconf', 'none']
# [16, 217757, 219384, 'lconf', 'coverage too low']
# [1, 552190, 552481, 'lconf', 'coverage too low']
# [6, 1961520, 1961960, 'hconf', 'none']
# [12, 60812, 61222, 'hconf', 'none']
# [0, 1976397, 1977203, 'hconf', 'none']
# [6, 900973, 901807, 'lconf', 'coverage too low']
# [4, 2131818, 2132257, 'hconf', 'none']
# [10, 1050034, 1050487, 'lconf', 'coverage too low']
# [5, 2217749, 2218809, 'hconf', 'none']
# [1, 1452317, 1452710, 'lconf', 'coverage too low']
# [12, 166191, 166938, 'lconf', 'coverage too low']
# [0, 1187006, 1187892, 'hconf', 'none']
# [2, 4759741, 4761979, 'lconf', 'coverage too low']
# [15, 553557, 554412, 'lconf', 'coverage too low']
# [1, 2377854, 2378954, 'hconf', 'none']
# [11, 908767, 909201, 'hconf', 'none']
# [0, 3506270, 3506684, 'hconf', 'none']
# [0, 4761021, 4761545, 'lconf', 'coverage too low']
# [18, 95565, 95891, 'lconf', 'coverage too low']
# [4, 1307439, 1308094, 'hconf', 'none']
# [0, 3597142, 3597920, 'lconf', 'coverage too low']
# [0, 1677271, 1677576, 'hconf', 'none']
# [3, 4171866, 4172255, 'lconf', 'coverage too low']
# [14, 740240, 740710, 'lconf', 'coverage too low']
# [12, 166183, 166938, 'lconf', 'coverage too low']
# [2, 4577058, 4577565, 'lconf', 'coverage too low']
# [4, 908287, 910420, 'hconf', 'none']
# [0, 701886, 702453, 'lconf', 'coverage too low']
# [10, 377797, 397579, 'lconf', 'coverage too low']
# [2, 2658183, 2658771, 'lconf', 'coverage too low']
# [26, 21600, 21900, 'lconf', 'coverage too low']
# [2, 4279858, 4283063, 'lconf', 'coverage too low']
# [1, 1782380, 1784095, 'hconf', 'none']
# [2, 4872041, 4877679, 'lconf', 'coverage too low']
# [3, 3689120, 3690061, 'lconf', 'coverage too low']

# %%
hconf_lowconf = list(map(checkcoverage, confirmed_list))

# %%
print(hconf_lowconf)
# Out:
# ['true', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'region too close to start', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'region too close to start', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'region too close to start', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low']

# %%
start_time = timeit.default_timer()
hconf_lowconf = list(map(checkcoverage, confirmed_list))
print(timeit.default_timer() - start_time)
# Out:
# 0.8786546527408063

# %%
start_time = timeit.default_timer()
hconf_lowconf_all = list(map(checkcoverage, confirmedall_list))
print(timeit.default_timer() - start_time)
# Out:
# 1350.8100269818678

# %%
print(hconf_lowconf_all)
# Out:
# ['true', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'region too close to start', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'region too close to start', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'region too close to start', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'region too close to end', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'region too close to start', 'true', 'true', 'true', 'true', 'true', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'coverage too low', 'true', 'coverage too low', 'true', 'true', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'coverage too low', 'cov ...
